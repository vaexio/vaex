# %%
import numpy as np
import vaex as vx
import pylab
# %matplotlib inline
#server = vx.server("localhost")
#names = server.list_datasets()

# %%
server = vx.server("localhost")
list = server.list_datasets()
print list
ds = server.open(list[0])
# Out:
# fetching http://localhost:5000/datasets
# [u'Aq-A-2-999-shuffled-10percent', u'Aq-A-2-999-shuffled-1percent', u'helmi-dezeeuw-2000-FeH']
# fetching http://localhost:5000/columns/Aq-A-2-999-shuffled-10percent
# columns [u'x', u'y', u'z', u'vx', u'vy', u'vz', u'ID', u'random_index']

# %%
list = server.list_datasets()
# Out:
# fetching http://localhost:5000/datasets

# %%
reload(vx)
reload(vx.dataset)
server = vx.server("localhost")
list = server.list_datasets()
print list
ds = server.open(list[0])
subspace = ds("x", "y")
limits = subspace.limits_sigma(square=True)
print limits
grid = subspace.histogram(limits=limits)
subspace.figlarge()
subspace.plot(np.log(grid+1), limits=limits, cmap="afmhot")
# Out:
# fetching http://localhost:5000/datasets
# [u'Aq-A-2-999-shuffled-10percent', u'Aq-A-2-999-shuffled-1percent', u'helmi-dezeeuw-2000-FeH']
# fetching http://localhost:5000/columns/Aq-A-2-999-shuffled-10percent
# columns [u'x', u'y', u'z', u'vx', u'vy', u'vz', u'ID', u'random_index']
# [[ 51.85119015  61.87997218]
#  [ 47.40265255  57.43143457]]
# fetching http://localhost:5000/histogram/Aq-A-2-999-shuffled-10percent
# data (256, 256) [[  4.   2.   1. ...,   5.   4.   4.]
#  [  2.   0.   3. ...,  10.   5.  11.]
#  [  4.   4.   0. ...,   8.   4.   6.]
#  ...,
#  [  5.   0.   2. ...,   1.   1.   0.]
#  [  0.   1.   0. ...,   2.   2.   1.]
#  [  0.   0.   1. ...,   0.   2.   0.]]

# %%
import ipy_autoreload

# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-42b861736920> in <module>()
# ----> 1 import ipy_autoreload
#       2
#       3 get_ipython().magic(u'load_ext autoreload')
#       4 get_ipython().magic(u'autoreload 2')
#
# ImportError: No module named ipy_autoreload

# %%
# %aimport vaex
# %aimport vaex.dataset

# %%
# %autoreload?

# %%
import autoreloadload
